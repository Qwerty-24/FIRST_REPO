# %%
# 1
a = int(input())
print(2*a)
# Out:
# 46

# %%
# 2
a, b, c = map(int, input().split())
print((a-b)*c)
# Out:
# 49

# %%
# 3
a = input()
print(chr(ord(a)+32))
# Out:
# a

# %%
# 4
n = int(input())
print(int(n/2)+1)
# Out:
# 5

# %%
# 5
n = int(input())
print(n**2 - n)
# Out:
# 12

# %%
# 6
_str = input()
print(_str[::-1])
# Out:
# nigga
