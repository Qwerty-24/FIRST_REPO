# %%
# 1
a = int(input())
print(2*a)
# Out:
# 46

# %%
# 2
a, b, c = map(int, input().split())
print((a-b)*c)
# Out:
# 49

# %%
# 3
a = input()
print(chr(ord(a)+32))
# Out:
# a

# %%
# 4
n = int(input())
print(int(n/2)+1)
# Out:
# 5

# %%
# 5
n = int(input())
print(n**2 - n)
# Out:
# 12

# %%
# 6
_str = input()
print(_str[::-1])
# Out:
# nigga

# %%
#18
n = int(input())
a = []
for i in range(0, n):
    a.append(str(input()))
print (a[0] + "\n" + a[n-1])
# Out:
# 2
# 8

# %%
#test
for i in range(1, 10, 0): #error: must not be 0
    print(i, end = ' ')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 #test
# ----> 2 for i in range(1, 10, 0):
#       3     print(i, end = ' ')
#
# ValueError: range() arg 3 must not be zero

# %%
#19
while True:
    n = int(input())
    if (n == 19): print(n); break
# Out:
# 19
