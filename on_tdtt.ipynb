# %%
#tat_bit_thap_nhat
def turn_off_lowest_bit(n):
    if n == 0:
        return 0
    return n&(n-1)

n = int(input())
print(turn_off_lowest_bit(n))
# Out:
# 0

# %%
#thua_so_ngto_tang_dan
def prime_factors(n):
    res = []
    d = 2
    tmp = n
    while d * d <= tmp:
        while tmp % d == 0:
            res.append(d)
            temp //= d
        d += 1
    if temp > 1:
        res.append(temp)
    return res

# %%
print(5+3>>4*3)
# Out:
# 0

# %%
x = 0
y = 5
z = 10
print(False and False or True)
# Out:
# True

# %%
price = int(input())
discount = int(input())
final_price = price - price * discount / 100
print(final_price)
# Out:
# 90.0

# %%
x = 3
y = 0
print((x > 0) and (y != 0) and (10 / y > 1))
# Out:
# False

# %%
a = True
b = False
c = False
if not a or b and c:
    print("YES")
else:
    print("NO")
# Out:
# NO

# %%
count = 0
for x in range(3):
    for y in range(3):
        if x == y:
            break
        count += 1
print(count)
# Out:
# 3
