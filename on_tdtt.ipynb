# %%
#tat_bit_thap_nhat
def turn_off_lowest_bit(n):
    if n == 0:
        return 0
    return n&(n-1)

n = int(input())
print(turn_off_lowest_bit(n))
# Out:
# 0

# %%
#thua_so_ngto_tang_dan
def prime_factors(n):
    res = []
    d = 2
    tmp = n
    while d * d <= tmp:
        while tmp % d == 0:
            res.append(d)
            temp //= d
        d += 1
    if temp > 1:
        res.append(temp)
    return res
