# %% [markdown]
# ### Problem 1
#
# #### Write a function `sum_1_to_n(n)` that **returns** the sum of all integers from 1 to `n`.  If `n` is non-positive, return 0.

# %%
def sum_1_to_n(n):
    if (n < 0): return 0
    sum = 0;
    for i in range(1, n+1):
        sum += i
    return sum

# %%
# Boundary and typical tests
assert sum_1_to_n(0) == 0
assert sum_1_to_n(-5) == 0
assert sum_1_to_n(1) == 1
assert sum_1_to_n(5) == 15
assert sum_1_to_n(10) == 55

# %% [markdown]
# ### Problem 2
#
# #### Write a function `sum_even_1_to_n(n)` that returns the sum of all even integers from 1 to `n` inclusive. If `n` is non-positive, return 0.

# %%
def sum_even_1_to_n(n):
    if (n < 0): return 0
    sum = 0
    for i in range(1, n+1):
        if (i & 1 == 0): # if not (i & 1)
            sum += i
    return sum

# %%
assert sum_even_1_to_n(0) == 0
assert sum_even_1_to_n(1) == 0
assert sum_even_1_to_n(2) == 2
assert sum_even_1_to_n(6) == 2 + 4 + 6
assert sum_even_1_to_n(7) == 2 + 4 + 6

# %% [markdown]
# ### Problem 3
#
# #### Write a function `sum_mod5_eq2_1_to_n(n)` that returns the sum of all integers `k` in `[1, n]` such that `k % 5 == 2`. If `n` is non-positive, return 0.

# %%
def sum_mod5_eq2_1_to_n(n):
    if (n < 0): return 0
    sum = 0
    for i in range(1, n+1):
        if (i % 5 == 2):
            sum += i
    return sum

# %%
assert sum_mod5_eq2_1_to_n(0) == 0
assert sum_mod5_eq2_1_to_n(2) == 2
assert sum_mod5_eq2_1_to_n(7) == 2 + 7
assert sum_mod5_eq2_1_to_n(12) == 2 + 7 + 12
assert sum_mod5_eq2_1_to_n(1) == 0

# %% [markdown]
# ### Problem 4
#
# #### Write a function `sum_multiples_upto_n(m, n)` that **returns** the sum of all numbers from 1 to `n` that are divisible by `m`.  If `n` is non-positive or `m` is 0, return 0.

# %%
def sum_multiples_upto_n(m, n):
    if (m <= 0 or n <= 0): return 0
    sum = 0
    for i in range(1, n+1):
        if (i % m == 0):
            sum += i
    return sum

# %%
# Boundary and typical tests
assert sum_multiples_upto_n(0, 10) == 0
assert sum_multiples_upto_n(3, 0) == 0
assert sum_multiples_upto_n(3, 10) == 18   # 3 + 6 + 9
assert sum_multiples_upto_n(2, 1) == 0
assert sum_multiples_upto_n(5, 25) == 75   # 5 + 10 + 15 + 20 + 25

# %% [markdown]
# ### Problem 5
#
# #### Write a function `square_matrix_of_n(n)` that **returns** a string representing an `n x n` matrix filled with the number `n`. Each row uses a single space between elements, and rows are separated by newline characters. If `n` is non-positive, return an empty string.

# %%
def square_matrix_of_n(n):
    s = ""
    for i in range (1, n+1):
        s += (f"{n} " * n).strip()
        s += "\n"

    s = s.rstrip()
    return s

# %%
assert square_matrix_of_n(0) == ""
assert square_matrix_of_n(-3) == ""
assert square_matrix_of_n(1) == "1"
assert square_matrix_of_n(2) == "2 2\n2 2"
assert square_matrix_of_n(3) == "3 3 3\n3 3 3\n3 3 3"

# %% [markdown]
# ### Problem 6
#
# #### Write a function `rectangle_of_char(n, m, c)` that **returns** a string representing a grid with `m` rows and `n` columns, containing the character `c`. Elements in each row are separated by a single space, and rows are separated by newline characters. If `n <= 0` or `m <= 0`, return an empty string.

# %%
def rectangle_of_char(n, m, ch):
    if (n <= 0 or m <= 0): return ""
    s = ""
    for i in range (1, m+1):
        s += (f"{ch} " * n).strip()
        s += "\n"

    s = s.rstrip()
    return s

# %%
assert rectangle_of_char(0, 3, "#") == ""
assert rectangle_of_char(3, 0, "#") == ""
assert rectangle_of_char(1, 1, "@") == "@"
assert rectangle_of_char(2, 3, "*") == "* *\n* *\n* *"
assert rectangle_of_char(4, 2, "X") == "X X X X\nX X X X"

# %% [markdown]
# ### Problem 7
#
# #### Write a function `inverted_triangle(n)` that returns a centered inverted triangle of asterisks with width `n`.
# - `n` must be a positive odd integer, otherwise return an empty string.
# - Each line has exactly `n` characters, decreasing by 2 asterisks per line until one remains.
#
# Example `n = 5` in test cases

# %%
def inverted_triangle(n):
    if not (n & 1): return ""
    s = ""

    for i in range(n, 0, -1):
        if (i & 1):
            k = (n-i)//2
            s += ' '*k + '*'*i + ' '*k + "\n"
    # print(s)
    s = s.strip("\n")
    return s

print(inverted_triangle(5))
# Out:
# *****
#  ***
#   *

# %%
tri5 = inverted_triangle(5).split("\n")
assert tri5[0] == "*****"
assert tri5[1] == " *** "
assert tri5[2] == "  *  "

assert inverted_triangle(1) == "*"
assert inverted_triangle(3) == "***\n * "
assert inverted_triangle(7) == "*******\n ***** \n  ***  \n   *   "

# %% [markdown]
# ### Problem 8
#
# #### Write a function `zigzag_numbers(n)` that **returns** a string representing an `n x n` matrix filled with the numbers from 1 to `n^2`. Rows are separated by newline characters. For row index starting at 0, even rows are left-to-right and odd rows are right-to-left. Within each row, numbers are concatenated without spaces (as in the example). If `n` is non-positive, return an empty string.

# %%
def zigzag_numbers(n):
    c = 1
    res = ""
    for i in range(1, n+1):
        s = ""
        if (i & 1):
            for j in range(1, n+1):
                s += f"{c}"
                c += 1
        else:
            for j in range(1, n+1):
                s = f"{c}" + s
                c += 1
        s += "\n"
        res += s
        
    res = res.strip("\n")
    return res

# print(zigzag_numbers(3))

# %%
z3 = zigzag_numbers(3).split("\n")
assert z3[0] == "123"
assert z3[1] == "654"
assert z3[2] == "789"

assert zigzag_numbers(0) == ""
assert zigzag_numbers(1) == "1"
assert zigzag_numbers(2) == "12\n43"

z4 = zigzag_numbers(4).split("\n")
assert z4[0] == "1234"
assert z4[1] == "8765"

# %% [markdown]
# ### Problem 9
#
# #### Write a function `count_solutions_3vars(a, b, c, t)` that returns the number of nonnegative integer solutions `(x, y, z)` to the equation `a*x + b*y + c*z = t`. Assume `a`, `b`, `c`, and `t` are integers. If `a <= 0` or `b <= 0` or `c <= 0` or `t < 0`, return 0.

# %%
def count_solutions_3vars(a, b, c, t):
    cnt = 0

    for x in range(0, int(t/a)+1):
        for y in range(0, int(t/b)+1):
            for z in range(0, int(t/c)+1):
                if (a*x + b*y + c*z == t):
                    cnt += 1
    return cnt

# %%
assert count_solutions_3vars(2, 2, 2, 1) == 0  # example
assert count_solutions_3vars(1, 1, 1, 1) == 3  # (1,0,0), (0,1,0), (0,0,1)
assert count_solutions_3vars(1, 2, 3, 0) == 1  # only (0,0,0)
assert count_solutions_3vars(1, 2, 3, 5) == 5  # at least (2,1,0)
assert count_solutions_3vars(1, 2, 3, 15) == 27  # at least (2,1,0)
assert count_solutions_3vars(-1, 2, 3, 5) == 0

# %% [markdown]
# ### Problem 10
#
# #### Write a function `is_prime(n)` that returns `True` if `n` is a prime number and `False` otherwise. By convention, numbers less than 2 are not prime.

# %%
def is_prime(n):
    if (n < 2): return False
    check = True

    for i in range (2, int(n**0.5)+1):
        if (n % i == 0): check = False

    return check

# %%
assert is_prime(0) is False
assert is_prime(1) is False
assert is_prime(2) is True
assert is_prime(17) is True
assert is_prime(21) is False
assert is_prime(226) is False
assert is_prime(331) is True

# %% [markdown]
# ### Problem 11
#
# #### Write a function `sum_divisors(a)` that **returns** the sum of all positive divisors of `a`.
# If `a <= 0`, return 0.

# %%
def sum_divisors(a):
    if (a <= 0): return 0
    sum = 0

    for i in range(1, int(a**0.5)+1):
        if (a % i == 0):
            sum += i
            if (i != int(a/i)):
                sum += a/i
                
    return sum

# %%
# Tests
assert sum_divisors(0) == 0
assert sum_divisors(-10) == 0
assert sum_divisors(1) == 1        # only divisor is 1
assert sum_divisors(6) == 12       # 1+2+3+6
assert sum_divisors(28) == 56      # 1+2+4+7+14+28
assert sum_divisors(9) == 13       # 1+3+9

# %% [markdown]
# ### Problem 12
#
# #### Write a function `is_perfect(n)` that returns `True` if `n` is a perfect number and `False` otherwise. A positive integer is perfect if it equals the sum of its positive proper divisors (excluding itself). By definition, `n` must be positive; for non-positive values, return `False`.

# %%
def is_perfect(n):
    if (n <= 1): return False
    
    sum_div = 0

    for i in range(1, int(n**0.5)+1):
        # print(i)
        if (n % i == 0):
            sum_div += i
            if (i != n/i):
                sum_div += n/i
    
    # print(sum_div)
    if (sum_div == n*2): return True
    else: return False

# %%
assert is_perfect(0) is False
assert is_perfect(1) is False
assert is_perfect(6) is True
assert is_perfect(28) is True
assert is_perfect(12) is False
