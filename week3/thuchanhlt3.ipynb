# %%
# Expressions in List Comprehension
li = [x**2 for x in range(10) if x & 1 == 0]
print(li)
# Out:
# [0, 4, 16, 36, 64]

# %%
a, b, c = map(int, input().split())
print(max(a, b, c))
# Out:
# 5

# %%
import datetime
td = datetime.datetime.today()
print(f"{td: %d - %b - %Y}")
# Out:
#  23 - Sep - 2025-1000

# %%
name = "Phat"
age = 30
print("My name is {0}, im {1}".format(name,age))
# Out:
# My name is Phat, im 30
